# %%
d ={}

# %%
type(d)
# Out:
# dict

# %%
student ={
    "name":"Kallo",
    "profession":"Berojgar",
    "kaam":"chutiya banana"
}

# %%
student["name"]
# Out:
# 'Kallo'

# %%
student["profession"]
# Out:
# 'Berojgar'

# %%
student["age"] = 67

# %%
student["age"]
# Out:
# 67

# %%
print(student)
# Out:
# {'name': 'Kallo', 'profession': 'Berojgar', 'kaam': 'chutiya banana', 'age': 67}

# %%
student.keys()
# Out:
# dict_keys(['name', 'profession', 'kaam', 'age'])

# %%
student.values()
# Out:
# dict_values(['Kallo', 'Berojgar', 'chutiya banana', 67])

# %%
student.items()
# Out:
# dict_items([('name', 'Kallo'), ('profession', 'Berojgar'), ('kaam', 'chutiya banana'), ('age', 67)])

# %%
student.update({"name":"Shubham"})

# %%
student.items()
# Out:
# dict_items([('name', 'Shubham'), ('profession', 'Berojgar'), ('kaam', 'chutiya banana'), ('age', 67)])

# %%
student.pop("name")
# Out:
# 'Shubham'

# %%
student
# Out:
# {'profession': 'Berojgar', 'kaam': 'chutiya banana', 'age': 67}

# %%
student.popitem()
# Out:
# ('age', 67)

# %%
student.setdefault("kaam")
# Out:
# 'chutiya banana'

# %%
student.setdefault("lalu")

# %%
student
# Out:
# {'profession': 'Berojgar', 'kaam': 'chutiya banana', 'lalu': None}
