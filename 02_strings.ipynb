# %%
name = "Shubham"

# %%
name
# Out:
# 'Shubham'

# %%
name.upper()
# Out:
# 'SHUBHAM'

# %%
name.lower()
# Out:
# 'shubham'

# %%
name.endswith("am")
# Out:
# True

# %%
name.endswith("kallo")
# Out:
# False

# %%
name.count("a")
# Out:
# 1

# %%
name.count("h")
# Out:
# 2

# %%
len(name)
# Out:
# 7

# %%
txt = "apple, banana, cherry"

# %%
txt.split()
# Out:
# ['apple,', 'banana,', 'cherry']

# %%
fruits = ['apple,', 'banana,', 'cherry']

# %%
print("".join(fruits))
# Out:
# apple,banana,cherry

# %%
text = "bat ball"

# %%
print(text.replace("ba", "ro"))
# Out:
# rot roll

# %%
senetence = "the quick fox"

# %%
senetence.find("fox")
# Out:
# 10

# %%
name[0:5] # string slicing
# Out:
# 'Shubh'

# %%
name[1:-1]
# Out:
# 'hubha'

# %%
name[1:6]
# Out:
# 'hubha'

# %%
name[-6:-1]
# Out:
# 'hubha'

# %%
name[1:6]
# Out:
# 'hubha'
