# %% [markdown]
# # Match Case
#
# - usecase : to simplify if else indentation

# %%
code = 500

# %%
match code:
    case 200:
        print("Response OK")
    case 400:
        print("Bad Response")
    case 404:
        print("Not found")
    case _:
        print("Default case")
# Out:
# Default case
