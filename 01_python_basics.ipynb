# %%
a = 5

# %%
b = 32

# %%
a + b
# Out:
# 37

# %%
str = "Shubham"

# %%
print(str)
# Out:
# Shubham

# %%
#this is a comment

# %%
print(type(str))
# Out:
# <class 'str'>

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
type(str)
# Out:
# str

# %%
p = "68964862"

# %%
q = "0734623"

# %%
print(p+q) # concatenates the string
# Out:
# 689648620734623

# %%
print(int(p) + int(q))
# Out:
# 69699485

# %%
int(p) + int(q) #type casting
# Out:
# 69699485
