# %%
a ={}

# %%
type(a)
# Out:
# dict

# %%
b = set()

# %%
type(b)
# Out:
# set

# %%
s = {2,4,5,8,4,63,67}

# %%
s
# Out:
# {2, 4, 5, 8, 63, 67}

# %%
s
# Out:
# {2, 4, 5, 8, 63, 67}

# %%
type_casting = set([1,2,5,6,3,4,2,8,7,6,5,9,8,7])

# %%
type_casting
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s.add(54)

# %%
s
# Out:
# {2, 4, 5, 8, 54, 63, 67}

# %%
s.update([5,89,65,45])

# %%
s
# Out:
# {2, 4, 5, 8, 45, 54, 63, 65, 67, 89}

# %%
s.remove(99)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 s.remove(99)
#
# KeyError: 99

# %%
s.discard(99)

# %%
s
# Out:
# {2, 4, 5, 8, 45, 54, 63, 65, 67, 89}

# %%
s.pop()
# Out:
# 65

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
set1 = {1,2,3,4}

# %%
set2 = {3,4,5,6}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {3, 4}

# %%
set1 | set2
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1 & set2
# Out:
# {3, 4}

# %%
sub = {1,3}

# %%
sub.issubset(set1)
# Out:
# True

# %%
set1.issuperset(sub)
# Out:
# True
