# %%
f = open("text.txt", "r")

# %%
f.read()
# Out:
# 'Shubham is good boy'

# %%
s = "this is the best way to learn Data Science"

# %%
f.close()

# %%
f = open("Shubham.txt", "w")

# %%
f.write(s)
# Out:
# 42

# %%
f.close()

# %%
with open("Shubham.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# this is the best way to learn Data Science
