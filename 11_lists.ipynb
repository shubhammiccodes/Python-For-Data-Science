# %%
l = [2,5,7,3,5]

# %%
l[0]
# Out:
# 2

# %%
l[3] = 8

# %%
l
# Out:
# [2, 5, 7, 8, 5]

# %%
l.append(100)

# %%
l
# Out:
# [2, 5, 7, 8, 5, 100]

# %%
l2 =[5,8]

# %%
l.append(l2)

# %%
l
# Out:
# [2, 5, 7, 8, 5, 100, [5, 8]]

# %%
l.extend(l2)

# %%
l
# Out:
# [2, 5, 7, 8, 5, 100, [5, 8], 5, 8]

# %%
l.insert(1,89)

# %%
l
# Out:
# [2, 89, 5, 7, 8, 5, 100, [5, 8], 5, 8]

# %%
l.pop(2)
# Out:
# 5

# %%
l.index(8)
# Out:
# 3

# %%
l
# Out:
# [2, 89, 7, 8, 5, 100, [5, 8], 5, 8]

# %%
l.count(5)
# Out:
# 2

# %%
l[6]
# Out:
# [5, 8]

# %%
l[6][1]
# Out:
# 8

# %%
l.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 l.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
l
# Out:
# [2, 5, 7, 8, 89, 100, [5, 8], 5, 8]

# %%
l.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 l.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
l1 = [5,3,6,2,8,4,9,2]

# %%
l1.sort()

# %%
l1
# Out:
# [2, 2, 3, 4, 5, 6, 8, 9]

# %%
sorted(l1)
# Out:
# [2, 2, 3, 4, 5, 6, 8, 9]

# %%
l5 = [4,6,7,8,4,5]

# %%
l6 = [6,4,5,3,9,1,2,2,3,4]

# %%
l5 + l6
# Out:
# [4, 6, 7, 8, 4, 5, 6, 4, 5, 3, 9, 1, 2, 2, 3, 4, 6, 4, 5, 3, 9, 1, 2, 2, 3, 4]

# %%
l5
# Out:
# [4, 6, 7, 8, 4, 5, 6, 4, 5, 3, 9, 1, 2, 2, 3, 4]
