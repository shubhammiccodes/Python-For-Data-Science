# %% [markdown]
# # Operator Precdence in Python
# ## PEMDAS - Parenthesis, exponents, multiple/div, add/sub

# %%
result = 10 + 2 * 3

# %%
result
# Out:
# 16

# %%
result = (10 + 2) * 3

# %%
result
# Out:
# 36

# %%
result = 2 ** 3 ** 2 # assocaitivity: right to left

# %%
result
# Out:
# 512
