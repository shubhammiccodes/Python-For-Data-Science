# %%
e = ()

# %%
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
l = []

# %%
type(l)
# Out:
# list

# %%
t =(5,6,3,4,5,5,3,8,9,7,8)

# %%
t
# Out:
# (5, 6, 3, 4, 5, 5, 3, 8, 9, 7, 8)

# %%
len(t)
# Out:
# 11

# %%
t[0]
# Out:
# 5

# %%
t[0] =65
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 t[0] =65
#
# TypeError: 'tuple' object does not support item assignment

# %%
per =("Kallo", 30,"Berojgar")

# %%
name, age, profession = per

# %%
name
# Out:
# 'Kallo'

# %%
age
# Out:
# 30

# %%
profession
# Out:
# 'Berojgar'

# %%
t.count(5)
# Out:
# 3

# %%
t.index(9)
# Out:
# 8
