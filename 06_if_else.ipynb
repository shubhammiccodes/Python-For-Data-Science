# %% [markdown]
# # Conditional statements in python

# %%
# if

# %%
a = 4

# %%
if (a> 54):
    print(" Greater")
else:
    print("Smaller")
# Out:
# Smaller

# %%
a = 41
if a > 50:
    print("greater than 50")
elif a > 40:
    print("greater than 40")
elif a > 30:
    print("greater than 30")
else:
    print("Done")
# Out:
# greater than 40

# %% [markdown]
# # use of if else , elif, match
#
# ## data cleaning, data filtering, decision making
