# %%
import json

# %%
obj = {"name": "shubham", "company":"accenture", "salary":"NA"}

# %%
formatted_json = json.dumps(obj, indent =4)

# %%
d = json.loads('{"name": "shubham", "company": "accenture", "salary": "NA"}')

# %%
type(d)
# Out:
# dict

# %%
file = open("data.json", "w")

# %%
json.dump(obj, file)

# %%
file.close()

# %%
print(formatted_json)
# Out:
# {
#     "name": "shubham",
#     "company": "accenture",
#     "salary": "NA"
# }
