# %%
class Employee:
    company = "HP"
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        
    def printDetails(self):
        print(f"The company of {self.name} is {self.company} with salary ${self.salary}")
        
    @staticmethod #decoarator and annotations
    def printTime():
        print(f"The time is now")

    @classmethod
    def printClassDetails(cls):
        print(f"the company is {cls.company}")
        


e = Employee("Harry", 47000)
e.printDetails()
e.printTime()
e.printClassDetails()
# Out:
# The company of Harry is HP with salary $47000
# The time is now
# the company is HP
