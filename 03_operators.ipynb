# %%
a = 10
b = 5

# %%
a+b
# Out:
# 15

# %%
a-b
# Out:
# 5

# %%
a * b
# Out:
# 50

# %%
a/b
# Out:
# 2.0

# %%
a//b
# Out:
# 2

# %%
2**2
# Out:
# 4

# %%
a % b
# Out:
# 0

# %%
a ** b
# Out:
# 100000

# %% [markdown]
# # Comparison Operator

# %%
a = 45

# %%
b =4

# %%
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a != b
# Out:
# True

# %% [markdown]
# # Logical Operators

# %%
b1 = True

# %%
b2 = False

# %%
not b1
# Out:
# False

# %%
not b2
# Out:
# True

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %% [markdown]
# # assignment Operator

# %%
a = 45

# %%
a += 4

# %%
a
# Out:
# 49

# %%
a = 45

# %%
a -= 5

# %%
a
# Out:
# 40

# %%
lst = [1, 2,3]

# %%
x=2

# %%
x in lst
# Out:
# True

# %%
x not in lst
# Out:
# False

# %%
a = "True"

# %%
b = "True"

# %%
a is b
# Out:
# True

# %%
a is not b
# Out:
# False
